# %% [markdown]
# # Sample Code

# %% [markdown]
# ## 基礎建設

# %%
import pandas as pd
import gzip, json

def parse(path):
    g = gzip.open(path, 'rb')
    for l in g:
        yield json.loads(l)

def getDF(path):
    i = 0
    df = {}
    for d in parse(path):
        df[i] = d
        i += 1
    return pd.DataFrame.from_dict(df, orient='index')

# %% [markdown]
# ## 載入資料

# %%
# !wget http://deepyeti.ucsd.edu/jianmo/amazon/categoryFilesSmall/All_Beauty.csv
# !wget http://deepyeti.ucsd.edu/jianmo/amazon/metaFiles2/meta_All_Beauty.json.gz
# Out:
# --2022-01-02 17:19:54--  http://deepyeti.ucsd.edu/jianmo/amazon/categoryFilesSmall/All_Beauty.csv
# Resolving deepyeti.ucsd.edu (deepyeti.ucsd.edu)... 169.228.63.50
# Connecting to deepyeti.ucsd.edu (deepyeti.ucsd.edu)|169.228.63.50|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15499476 (15M) [application/octet-stream]
# Saving to: ‘All_Beauty.csv.1’
#
# All_Beauty.csv.1    100%[===================>]  14.78M  10.1MB/s    in 1.5s
#
# 2022-01-02 17:19:56 (10.1 MB/s) - ‘All_Beauty.csv.1’ saved [15499476/15499476]
#
# --2022-01-02 17:19:56--  http://deepyeti.ucsd.edu/jianmo/amazon/metaFiles2/meta_All_Beauty.json.gz
# Resolving deepyeti.ucsd.edu (deepyeti.ucsd.edu)... 169.228.63.50
# Connecting to deepyeti.ucsd.edu (deepyeti.ucsd.edu)|169.228.63.50|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10329961 (9.9M) [application/octet-stream]
# Saving to: ‘meta_All_Beauty.json.gz.1’
#
# meta_All_Beauty.jso 100%[===================>]   9.85M  6.92MB/s    in 1.4s
#
# 2022-01-02 17:19:58 (6.92 MB/s) - ‘meta_All_Beauty.json.gz.1’ saved [10329961/10329961]

# %%
metadata = getDF('/content/meta_All_Beauty.json.gz')
ratings = pd.read_csv('/content/All_Beauty.csv', names=['asin', 'reviewerID', 'overall', 'unixReviewTime'], header=None)

# %%
ratings.head()
# Out:
#          asin      reviewerID  overall  unixReviewTime
# 0  0143026860  A1V6B6TNIC10QE      1.0      1424304000
# 1  0143026860  A2F5GHSXFQ0W6J      4.0      1418860800
# 2  0143026860  A1572GUYS7DGSR      4.0      1407628800
# 3  0143026860   A1PSGLFK1NSVO      5.0      1362960000
# 4  0143026860   A6IKXKZMTKGSC      5.0      1324771200

# %%
metadata.shape
# Out:
# (32892, 19)

# %% [markdown]
# # 資料整理

# %%
ratings['DATE'] = pd.to_datetime(ratings['unixReviewTime'], unit='s')

# %% [markdown]
# # 資料切分

# %%
ratings_trainings = ratings[
    (ratings['DATE'] < '2018-09-01')
]
ratings_testings = ratings[
    (ratings['DATE'] >= '2018-09-01') & 
    (ratings['DATE'] <= '2018-09-30')
]
ratings_testings_by_user = ratings_testings.groupby('reviewerID').agg(list).reset_index()[['reviewerID', 'asin']].to_dict('records')
ratings_testings_by_user = { rating['reviewerID']: rating['asin'] for rating in ratings_testings_by_user }
users = list(ratings_testings_by_user.keys())

# %% [markdown]
# # 產生需要的欄位

# %%
# 產生舊客的 metadata 表

# 處理 rank 中的排行跟分類
metadata['rank_rank'] = metadata['rank'].str.split(" ").str.get(0).str.replace(',','').to_frame()
metadata['rank_category'] = metadata['rank'].str.split("in ").str.get(1).to_frame()


# 將 details 轉為字串
metadata_discover = metadata['details']
tmp = metadata['details']
for i in range(len(metadata_discover)):
  tmp.iloc[i]=json.dumps(metadata_discover.iloc[i]).lower()
metadata['details_str']=tmp


# 抽取需要的欄位
df_asin = metadata['asin'].to_frame()
df_title = metadata['title'].str.lower().to_frame()
df_description = metadata['description'].str[0].str.lower().to_frame()
df_brand = metadata['brand'].str.lower().to_frame()
df_rank_category = metadata['rank_category'].str.lower().to_frame()
df_details_str = metadata['details_str'].str.lower().to_frame()


# 產生新的 metadata 表
metadata_tmp = pd.concat([df_asin,df_title,df_description,df_brand,df_rank_category,df_details_str],axis='columns')
#metadata_tmp2 = metadata_tmp.set_index('asin')


# 移除重複的資料
metadata_tmp3=metadata_tmp.drop_duplicates(subset=None, keep='first', inplace=False)
metadata_tmp3.reset_index(inplace=True)

# %%
metadata_tmp3['text'] = metadata_tmp3['title'].str.cat(metadata_tmp3['rank_category'],sep=" ")
metadata_for_old=metadata_tmp3
metadata_for_old
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        index  ...                                               text
# 0          0  ...  loud 'n clear&trade; personal sound amplifier ...
# 1          1  ...  no7 lift &amp; luminate triple action serum 50...
# 2          2  ...  no7 stay perfect foundation cool vanilla by no...
# 3          3  ...  wella koleston perfect hair colour 44/44 mediu...
# 4          4  ...  lacto calamine skin balance oil control 120 ml...
# ...      ...  ...                                                ...
# 32483  32887  ...  barielle pro textured grip cuticle nipper, pur...
# 32484  32888  ...  (buy 3 get 1 free) salon perfect eye makeup co...
# 32485  32889  ...  now d-mannose 500 mg - 120 veg capsules (pack ...
# 32486  32890  ...  12 white feather shuttlecocks birdies badminto...
# 32487  32891  ...  feshfen scrunchy scrunchies synthetic hair bun...
#
# [32488 rows x 8 columns]

# %%
# 產生新客的 metadata 表

df_asin = metadata['asin']
df_brand = metadata['brand']
df_title = metadata['title']
df_price = metadata['price']
df_rank = metadata['rank'].str.split(" ").str.get(0).str.replace(',','')
df_rank2 = pd.to_numeric(df_rank, errors='coerce')
df_description = metadata['description']
df_imageURL = metadata['imageURL'].str[0].str.lower().to_frame()
metadata_tmp = pd.concat([df_asin,df_brand,df_title,df_price,df_rank2,df_description,df_imageURL],axis='columns')
metadata_new = metadata_tmp.set_index('asin')
metadata_new['overall_mean'] = ratings.groupby(by=['asin']).mean()['overall']
metadata_new['reviews_count'] = ratings.groupby(by=['asin']).size()


# 抽取商品評分最後日期
ratings_asin=ratings_trainings['asin']
ratings_date=ratings_trainings['DATE']
ratings_tmp = pd.concat([ratings_asin,ratings_date],axis='columns')
ratings_max_dt=ratings_tmp.groupby('asin').DATE.max().to_frame()
ratings_max_dt


metadata_new=pd.merge(metadata_new,ratings_max_dt,how='left', on=['asin'])
metadata_for_new=metadata_new
metadata_for_new
# Out:
#                         brand  ...       DATE
# asin                           ...
# 6546546450       idea village  ... 2013-08-13
# 7178680776                     ... 2017-10-06
# 7250468162                No7  ... 2017-08-26
# 7367905066                     ... 2017-04-12
# 7414204790  Pirmal Healthcare  ... 2018-03-02
# ...                       ...  ...        ...
# B01HIWLLUK                     ... 2016-09-24
# B01HJ1K3YK      Salon Perfect  ... 2017-04-21
# B01HJ84SGM                     ... 2018-03-23
# B01HJASD20            GBSTORE  ... 2016-08-31
# B01HJEGTYK                     ... 2018-06-27
#
# [32892 rows x 9 columns]

# %% [markdown]
# # 資料探索過程

# %%
## description	also_buy feature also_view	imageURL	imageURLHighRes
metadata_discover=metadata['imageURLHighRes'].str[0].str.lower().to_frame()
aa=metadata_discover.groupby('imageURLHighRes').imageURLHighRes.count().reset_index(name='count').sort_values(['count'], ascending=False)
aa
#aa.iloc[4898].imageURLHighRes
#aa.loc[(aa['count'] == 1)]
#bb=metadata_discover.isnull().sum()
#bb
# Out:
#                                          imageURLHighRes  count
# 5575   https://images-na.ssl-images-amazon.com/images...     38
# 3618   https://images-na.ssl-images-amazon.com/images...     29
# 14872  https://images-na.ssl-images-amazon.com/images...     25
# 11803  https://images-na.ssl-images-amazon.com/images...     19
# 5473   https://images-na.ssl-images-amazon.com/images...     16
# ...                                                  ...    ...
# 5331   https://images-na.ssl-images-amazon.com/images...      1
# 5332   https://images-na.ssl-images-amazon.com/images...      1
# 5333   https://images-na.ssl-images-amazon.com/images...      1
# 5334   https://images-na.ssl-images-amazon.com/images...      1
# 15541  https://images-na.ssl-images-amazon.com/images...      1
#
# [15542 rows x 2 columns]

# %%
##category	tech1	fit	title	tech2	brand	details	main_cat	similar_item	asin	date price rank0 rank1 details_str
metadata_discover=metadata['asin'].str.lower().to_frame()
aa=metadata_discover.groupby('asin').asin.count().reset_index(name='count').sort_values(['count'], ascending=False)
aa
#aa.iloc[2].price
#aa.iloc[3529]
#aa.loc[(aa['count'] == 1)]
# Out:
#              asin  count
# 327    b00027c9au      2
# 292    b00021di10      2
# 290    b00021cwyo      2
# 289    b00021cqta      2
# 288    b00021cpnc      2
# ...           ...    ...
# 11092  b00h41ddck      1
# 11091  b00h412x2g      1
# 11090  b00h412qc8      1
# 11089  b00h3vqvqg      1
# 32487  b01hjegtyk      1
#
# [32488 rows x 2 columns]

# %%
## asin	reviewerID
ratings_discover=ratings['asin'].str.lower().to_frame()
aa=ratings_discover.groupby('asin').asin.count().reset_index(name='count').sort_values(['count'], ascending=False)
aa
#aa.iloc[2].price
#aa.iloc[3529]
#aa.loc[(aa['count'] == 1)]
# Out:
#              asin  count
# 939    b000foi48g   8672
# 1059   b000glrreu   8341
# 59     1620213982   4792
# 3301   b001qy8qxm   4544
# 29555  b01dkqaxc0   4246
# ...           ...    ...
# 10564  b00g70etsq      1
# 22343  b0131jvk8c      1
# 10558  b00g6exfg0      1
# 10556  b00g6214la      1
# 8490   b00cchaiu6      1
#
# [32586 rows x 2 columns]

# %%
ratings_trainings.count()
# Out:
# asin              370752
# reviewerID        370752
# overall           370752
# unixReviewTime    370752
# DATE              370752
# dtype: int64

# %%
ratings_testings.count()
# Out:
# asin              590
# reviewerID        590
# overall           590
# unixReviewTime    590
# DATE              590
# dtype: int64

# %%
### asin reviewerID 查看交集狀況
column_asin = ["asin"]
ratings_trainings_item = pd.DataFrame(ratings_trainings['asin'].unique(),columns=column_asin)
ratings_testings_item = pd.DataFrame(ratings_testings['asin'].unique(),columns=column_asin)

ratings_trainings_item = ratings_trainings_item.set_index('asin')
ratings_testings_item = ratings_testings_item.set_index('asin')

#ratings_trainings_item.join(ratings_testings_item, how='inner')
pd.merge(ratings_trainings_item,ratings_testings_item,how='inner', on=['asin'])
# Out:
# Empty DataFrame
# Columns: []
# Index: [B013XKHA4M, B015L947B2, B015P54DHU, B015PFP72A, B015SG1BSU, B015YL6MYM, B015ZTNN7W, B0168SXRR0, B016YROO36, B0174MNPNU, B0176882A8, B0178H2LK4, B017BFMTVE, B017BJ8KFE, B017I6B6GK, B017JBTB98, B017JSZKGY, B017KQGXS4, B017M402PO, B017STUIG6, B017TNICB4, B017WIFR7S, B017X2K6R4, B01814GS02, B01826KTDQ, B01868X158, B0189H1QKS, B0189NOD4I, B018IW1T5Q, B018J05XSQ, B018MPUY32, B018SFOZYA, B018SFIGXG, B018WCT01C, B0191JMIO6, B0191W80SQ, B0195R1FT8, B019CSBH8E, B019EUWONW, B019FWRG3C, B019KVY1M2, B019QBT4KA, B01A1DW4ZE, B01A2V64EW, B01AAVIO38, B01AHSUT8M, B01AIFGCSK, B01AMOTPI6, B01AS25Y0U, B01ASFQX0M, B01AVERN9K, B01AVJCDYA, B01AWA2WIU, B01AWCELHS, B01AWXGD3M, B01AX2X5W4, B01B09T9QK, B01B18T01Y, B01B3R5EFO, B01B50CBD2, B01B55GPS4, B01B9OEDKS, B01BEWYRJ2, B01BHN3EHE, B01BI4O5IY, B01BI52N5U, B01BI8YFAS, B01BK1E7Q0, B01BNEYGQU, B01BNYL30M, B01BT3FPPG, B01BUP23IK, B01BV7MUZ8, B01BX1P41Y, B01BYNTXXQ, B01BZV6VVY, B01C39X6TW, B01C3GS7NA, B01C4ZAPGM, B01C64NN8I, B01C6MIGU0, B01C73D72U, B01C8DU5WO, B01CD7JK9E, B01CE16I94, B01CG8DLN6, B01CGU3DXC, B01CJNZKZK, B01CNGL9VC, B01COBI3BK, B01COJLMME, B01CQ4X6C6, B01CQSJF9U, B01CRSWZAU, B01CS0V0XK, B01CSVKEYK, B01CT95TFK, B01CTIJEIY, B01CTQC9J2, B01CW24JXC, ...]
#
# [331 rows x 0 columns]

# %% [markdown]
# # 新客熱門商品

# %%
# 優質熱門商品

popular_products = metadata_for_new.loc[(metadata_for_new['overall_mean'] >= 4) & (metadata_for_new['reviews_count'] >= 100) ].sort_values(by=['imageURL','DATE','reviews_count','overall_mean',], ascending=False)
popular_products.reset_index(inplace=True)
popular_products.head(10)
fix_recommend_top10=popular_products['asin'].unique()[0:10].tolist()
fix_recommend_top10
# Out:
# ['B000G8LWZI',
#  'B000FTYALG',
#  'B01C39X6TW',
#  'B000WN2T2M',
#  'B001V9FPHM',
#  'B00HY7S61W',
#  'B018SFIGXG',
#  'B018SFOZYA',
#  'B00021DJ32',
#  'B001G8LKBS']

# %% [markdown]
# ## 舊客產生推薦

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# 計算商品用標題所表示的 tfidf 矩陣
df = metadata.drop_duplicates('title')
tf = TfidfVectorizer(analyzer='word')
tfidf_matrix = tf.fit_transform(df['title'])

# 計算商品間的相似程度
from sklearn.metrics.pairwise import cosine_similarity
similarity_matrix = cosine_similarity(tfidf_matrix)
mapping = pd.Series(df.index,index = df['title'])

# 每個商品回傳 k 個最相近的商品
def recommend_item(item_input, k=10):
    try:
        item_index = mapping[item_input]
        similarity_score = list(enumerate(similarity_matrix[item_index]))
        similarity_score = sorted(similarity_score, key=lambda x: x[1], reverse=True)
        similarity_score = similarity_score[:k]
        item_indices = [i[0] for i in similarity_score]
        return (df['asin'].iloc[item_indices].tolist())
    except:
        return []

# 利用使用者購買過的商品產生推薦
def recommend_items(items, k):
    
    res = []
    for d in items:
        res.extend(recommend_item(d, k))
    return res

# %%
def recommend_rule_and_content(items, k, user):
  
  user_in_trainings = ratings_trainings.loc[(ratings_trainings['reviewerID']==user)]
  
  if user_in_trainings.empty:
    recommend_topk=fix_recommend_top10
  else:
    recommend_topk=recommend_items(items, k)
  return recommend_topk

# %%
def recommender(training_data, users=[], k=10):
    '''
    * training_data: dataframe 輸入的訓練資料集（2018-09-01 以前資料）
    * users: [] 需要被推薦的使用者
    * k: int 每個使用者需要推薦的商品數
    * recommendations: dict
      {
          使用者一： [推薦商品一, 推薦商品二, ...],
          使用者二： [...], ...
      }
    '''
    recommendations = {}
    '''
    content-based
    '''
    ratings_trainings = training_data
    recommendations = {user: recommend_rule_and_content(metadata_for_old[metadata_for_old['asin'].isin(ratings_trainings[ratings_trainings['reviewerID'] == user]['asin'].tolist())]['text'].tolist(), k, user) for user in users}
    return recommendations

ratings_by_user = recommender(ratings_trainings, users)
ratings_by_user
# Out:
# {'A100XQFWKQ30O2': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A103T1QOGFCSEH': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A106UKKSJ2KXPF': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A10A7GV4D5A11V': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1119JJ37ZLB8R': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A113UOOLBSZN52': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A12M4U7WK4ALCR': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A12T8YTW6VWT7S': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1364JXGKB46MM': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A137DALOQFKBTI': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A13FEZ3WV7S2EY': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A13IV4I1B0RXMG': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A13JU88JAHN72I': [],
#  'A13K55R6VH1OOD': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A13P7VFU075A': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A13SWYE4QLB6NG': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A13ZTQ0Q4ATA41': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A142EDN04OD62U': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A142I22FIC8MZK': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A14834QTII5TLT': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A14A447VPACTBC': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A14AP6MN5XO6LB': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A14CLF25IX25US': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A14LYXC3HTBAHI': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A14VUW4KZ34EOE': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A14Y32P26G9YL': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A157T25PBS7MX4': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A15HZDSERD85C8': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A15JJ8J1FGADIX': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A15ZCL70JXXH89': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1617KN2IAWZ6J': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A16E0O88262HKA': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A16NSZ58PTVIYF': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A16UGDXRTDLJG5': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A16X9HR3UFQQXY': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A16Y7V1CZCWKFV': [],
#  'A174YOBOSW9WDN': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1786SKRAJXH86': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A17K2BUZ20WD2': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A17LYRFV645L0V': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A18LNGVXDZBTUR': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A19503XX7GU6J2': [],
#  'A19HVHRZDYFEOP': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A19JM38B861BO4': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A19KGY3W1P0MHT': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A19KJPOF3QOJ24': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A19U5RT4Q8Q1T6': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1AQNQUNX8B6JT': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1ARU0IN6RUFFD': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1BB4635KSKDMV': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1BCC7X6KRTBG0': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1BPJ56BXENC7': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1C0RI6W65FC8B': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1C60LJGZVEK27': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1CB2SMS3TD44Z': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1CNSU8P68CPLT': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1CSDWBYUJBCJZ': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1CTNNVIYHO25P': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1CTQF97HFYOZB': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1D5C2H9UFZHPU': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1D5UVH72Z6NJ1': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1DAUVZRVSLLNW': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1DCZ9882PXLVB': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1DZ63D35BNT86': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1E0QCKB4R2X8X': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1E76OZZ5YUWVA': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1EBHZPAYMILW9': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1EJVNGBY5GM5I': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1ER0356V2DSKW': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1EY751AUVO5NZ': [],
#  'A1EZFX1TRHSAJX': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1F08GM4B97FV': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1F6EFMBK795DJ': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1FC8Y896NZP4T': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1FKIAKVOBNN7Y': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1FKUBRPLG6Y8I': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1G2HL4W8B3TA0': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1G8Z9IKJ0BD1M': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1GEJ55RJGD7JW': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1GIYGD23YIDTN': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1GLG2IZBZHRAJ': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1H1T82FPO20DN': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1H7JDZ9BKTKGC': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1HBROZPSV5KT6': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1HBXMUIHTAIU2': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1I32A4SA9W2L2': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1IDJ6KR8CQV9I': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1II0TTUUE2C7Y': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A1ILEZFIVOU0EP': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'A
['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AFE9H6ABXM735': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AFMQ7BBR4FYMB': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AFY8EIWAT6H8J': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AG0867QGE3R2B': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AG3T3ILPXFL3H': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AG74ZKO3BG57J': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AGORXWI6K2RIR': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AGRZQOBCF8H87': [],
#  'AGTD0T9R78YLG': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AGYIYIVZHBI60': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AHGNU4UWGATOH': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AHYRXYR235TWH': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AIB7HX2UC3WHM': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AITF34BGBMVJJ': [],
#  'AIU7HYQIC5D95': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AJHSB0LT8NKP4': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AJYMJEC6B7V52': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AK4VANLR5UK95': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AK7YIZE6ZZ1N9': [],
#  'AKHSKD91MQ9DP': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'ALUZH689LQE6K': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'ALWLZC3GRRXPN': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AM1KUDVTKXIAQ': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AM9HBLGAPZQR7': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AMA98TY969A1T': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AMLDY4QY4HV0D': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AMVZ9HW23Y42N': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AN3QZR3OD7SFO': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'ANC6FN6T8JBB2': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'ANDGVKQ15NCZM': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'ANFUWUOC7EJKR': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'ANG7MOYBTWQE6': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'ANJ6Y9G0B4TM8': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'ANR73TPVBCQ9K': [],
#  'ANT034IX5ZPI9': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AOB2Y1KJQG7K7': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AONHG4PDUQ0D6': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'APA9SALOTTBM6': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'APARJQGAD0J4C': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AQ5PKYF0FJA4B': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AQCQQYEUHUX3M': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AQYL4TDY2HU8Z': [],
#  'AR9Y0CM5B174': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'ARLN791TA1RV7': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AS8T77HTF9IHW': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'ASGIVOW34XNQS': [],
#  'ATJRZUXNWAWIK': [],
#  'ATP2UCHTR7QMZ': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'ATR9J7TYR1KVL': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'ATVP6QJLS27EN': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AU03W1V42994X': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AU1BVXGV2KO8I': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AU2JWZMFEVAH5': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AU3MVNMVFSIM': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AUKMWTDK16PAP': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AUWJT1DM7SG2D': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AV0O5NWF2NKDF': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AV2MC7NNTMKTF': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AVC89473DX6XU': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AVFBQDR2KRNK6': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AVIMJH2FF6QCH': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AVO5FL5T9EZSR': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AVQ0V2MIW2Z5K': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AVWSUUBWD3RK4': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AWJFUVK3064HX': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AXM9OKKHRR4RP': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AXPZI9N8HVHYO': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AXQ57AZLKLPCQ': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AXQS1B3WVRHQV': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AXS7NH3GDN7EE': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AY4F95T0JSTZ2': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AYG63OK9TNBNP': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AZE64W03EUJA4': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AZECTAHZICNW5': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AZEGZXCFTLSQB': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AZEKC7DEXXJD7': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AZFGSCB0S59LQ': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS'],
#  'AZHS42HV4FKKA': ['B000G8LWZI',
#   'B000FTYALG',
#   'B01C39X6TW',
#   'B000WN2T2M',
#   'B001V9FPHM',
#   'B00HY7S61W',
#   'B018SFIGXG',
#   'B018SFOZYA',
#   'B00021DJ32',
#   'B001G8LKBS']}

# %% [markdown]
# ## 結果評估

# %%
def evaluate(ratings_testings_by_user={}, ratings_by_user={}, method=None):
    '''
    * ratings_testings_by_user: dict 真實被購買的商品資料（2018-09-01 以後資料）
    * ratings_by_user: dict 利用訓練資料學習的推薦商品
    * method: str
    * score: float
    '''
    total = 0
    for d in ratings_testings_by_user:
        if d in ratings_by_user:
            total += len(set(ratings_by_user[d]) & set(ratings_testings_by_user[d]))

    score = total / len(ratings_testings)
    return score

evaluate(ratings_testings_by_user, ratings_by_user)
# Out:
# 0.00847457627118644
